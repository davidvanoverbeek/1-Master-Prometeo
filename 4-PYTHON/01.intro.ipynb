# %% [markdown]
# ## ASISTENTE DE VISUAL PARA CODIGO MARKDOWN

# %% [markdown]
# ## Tecnologias utilizadas
#
# - Jupyter Notebook
# - Markdown
# - Python

# %%
# Este es un script con salida "Hola mundo!"
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ### Esta es mi segunda ejecucion con Python y Jupyter Notebook

# %%
print("Adios")
# Out:
# Adios

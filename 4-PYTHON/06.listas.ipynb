# %% [markdown]
# ## Listas

# %%
lista = ["Iron man", "Spiderman", "Hulk", 42, True]
print(lista)
print(lista[0])
print(len(lista))
# Out:
# ['Iron man', 'Spiderman', 'Hulk', 42, True]
# Iron man
# 5

# %% [markdown]
# #### Listas Anidadas

# %%
marvel = [
    ["Ciclope", "wolverine", "Fenix"],
    ["Iron Man", "Spiderman", "Elektra"],
    ["Daredevil", "Punisher", "Elektra"]
]

print(marvel[1][1])
# Out:
# Spiderman
